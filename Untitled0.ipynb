# %% [markdown]
# <a href="https://colab.research.google.com/github/H00wb/emotion-recognition-using-speech/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
